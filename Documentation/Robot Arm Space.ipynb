# %% [markdown]
# # Robot Arm Space

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.style.use('seaborn-whitegrid')
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

x = np.linspace(0, 10)
ax.plot(x, x, x)

y = np.linspace(10, 20)
ax.plot(y, -y, -y)

# x = np.linspace(0, 10, 1000)
# ax.plot(x, x, x);

# %% [markdown]
# \begin{equation}
#     A_{1} = \begin{bmatrix}
#         c_{1}&−s_{1}&0&a_{1}c_{1} \\
#         s_{1}&c_{1}&0&a_{1}s_{1} \\
#         0&0&1&0 \\
#         0&0&0&1
#     \end{bmatrix}
# \end{equation}
#
# \begin{equation}
#     A_{2} = \begin{bmatrix}
#         c_{2}&−s_{2}&0&a_{2}c_{2} \\
#         s_{2}&c_{2}&0&a_{2}s_{2} \\
#         0&0&1&0 \\
#         0&0&0&1
#     \end{bmatrix}
# \end{equation}
#
# \begin{equation}
#     A_{3} = \begin{bmatrix}
#         c_{3}&−s_{3}&0&a_{3}c_{3} \\
#         s_{3}&c_{3}&0&a_{3}s_{3} \\
#         0&0&1&0 \\
#         0&0&0&1
#     \end{bmatrix}
# \end{equation}

# %% [markdown]
# \begin{equation}
#     T^{0}_{1} = A_{1}
# \end{equation}
# \begin{equation}
#     T^{0}_{2} = A_{1}A_{2} = \begin{bmatrix}
#         c_{12}&−s_{12}&0&a_{1}c_{1} + a_{2}c_{12} \\
#         s_{12}&c_{12}&0&a_{1}s_{1} + a_{2}c_{12} \\
#         0&0&1&0 \\
#         0&0&0&1
#     \end{bmatrix}
# \end{equation}

# %% [markdown]
# ## Now there is another joint that needs to be added

# %% [markdown]
# \begin{equation}
#     T^{0}_{2} = A_{1}A_{2}A_{3} = \begin{bmatrix}
#         c_{12}&−s_{12}&0&a_{1}c_{1} + a_{2}c_{12} \\
#         s_{12}&c_{12}&0&a_{1}s_{1} + a_{2}c_{12} \\
#         0&0&1&0 \\
#         0&0&0&1
#     \end{bmatrix}
#     \begin{bmatrix}
#         c_{3}&−s_{3}&0&a_{3}c_{3} \\
#         s_{3}&c_{3}&0&a_{3}s_{3} \\
#         0&0&1&0 \\
#         0&0&0&1
#     \end{bmatrix}
# \end{equation}
